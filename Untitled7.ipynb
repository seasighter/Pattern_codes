# %% [markdown]
# pattern furstrating

# %%
n= int(input())
row=1
while row <= n:
    space= n-row
    while space>0:
        print(" ",end="")
        space-=1
    #print("\r")
    col=1
    while col<=row:
        print("*",end="")
        col+=1
    print("\r")
    row+=1
# Out:
# 5
#     *
#    **
#   ***
#  ****
# *****

# %% [markdown]
# opposite of above

# %%
n= int(input())
i=1
while i <= n:
    j=0
    while j<=(n-i):
        print("*",end=" ")
        j+=1
    print("\r")
    i+=1
# Out:
# 4
# * * * *
# * * *
# * *
# *

# %%
n= int(input())
row=1
while row <= n:
    # printing spaces
    space=row-1
    while space > 0:
        print(" ",end=" ")
        space-=1
    #print("\r")
    col=1
    while col <= n-row:
        print("*",end=" ")
        col=+1
    print("\r") 
    row+=1
# Out:
# 3
# ...
